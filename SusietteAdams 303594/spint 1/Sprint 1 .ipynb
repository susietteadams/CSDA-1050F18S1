# %% [markdown]
# # Analysing housing rent prices using 3 datasets. The datasets were extracted from the CMHC websit they are housing price indicaters, household average income and average price for 2 bedroom apartments.
#
# There is still a lot of work to be done on this project, but for the most part the the infprmation below will give you a good grasp of datasets.
#
# Susiette Adams 3030594

# %%
# Loading packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pandas import read_table
# %matplotlib inline

# %%
# Importing the Renter Household data
rent= pd.read_csv(r"C:\\Users\\susie\\Documents\\Data Science\\Capstone data\\Average price 2 bedrooms.csv"
                   ,encoding="latin")
rent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 26 columns):
# City    34 non-null object
# 1992    34 non-null int64
# 1993    34 non-null int64
# 1994    34 non-null int64
# 1995    34 non-null int64
# 1996    34 non-null int64
# 1997    34 non-null int64
# 1998    34 non-null int64
# 1999    34 non-null int64
# 2000    34 non-null int64
# 2001    34 non-null int64
# 2002    34 non-null int64
# 2003    34 non-null int64
# 2004    34 non-null int64
# 2005    34 non-null int64
# 2006    34 non-null int64
# 2007    34 non-null int64
# 2008    34 non-null int64
# 2009    34 non-null int64
# 2010    34 non-null int64
# 2011    34 non-null int64
# 2012    34 non-null int64
# 2013    34 non-null int64
# 2014    34 non-null int64
# 2015    34 non-null int64
# 2016    34 non-null int64
# dtypes: int64(25), object(1)
# memory usage: 7.0+ KB

# %%
# The type() function is used to know the data structure of a dataset.
type(rent)
# Out:
# pandas.core.frame.DataFrame

# %%
# The output above tells us that it is a pandas core frame object. Next we import the DataFrame object from pandas.

# %%
# Importing pandas dataframe
from pandas.core.frame import DataFrame

# %%
# We print the field names of the dataset using the keys() function to understand the features of the dataset. 
rent.keys()
# Out:
# Index(['City', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
# Taking a peek at the data the rent.head function inly returns the first five rows because there are 26 columns we are unable to see all of them.
print(rent.head())
# Out:
#                         City  1992  1993  1994  1995  1996  1997  1998  1999  \
# 0                    Canada2   568   575   579   589   593   597   616   628
# 1  Newfoundland and Labrador   517   512   517   525   526   524   490   489
# 2       Prince Edward Island   503   511   517   523   522   527   529   531
# 3                Nova Scotia   562   571   579   584   588   589   603   609
# 4              New Brunswick   461   470   479   484   490   499   503   510
#
#    2000  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   648  ...   772   804   812   835   856   875   894   915   939   962
# 1   510  ...   575   596   634   668   701   725   784   812   834   865
# 2   538  ...   648   660   688   719   745   787   790   819   814   852
# 3   621  ...   777   795   838   851   882   909   929   955   992  1008
# 4   515  ...   619   635   656   668   687   707   715   735   744   763
#
# [5 rows x 26 columns]

# %%
# The .to_string() method give a much better view of the data contents and I have selecting 10 rows to view
print(rent.head(10).to_string())
# Out:
#              City  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  u_medf  2014_medf
# 0      St. JohnÕs   566   554   559   565   570   567   513   517   552   575   589   607   618   634   635   614   630   677   725   771   798   864   888   923   958     888        888
# 1         Halifax   595   604   610   615   617   616   631   637   648   673   704   720   747   762   799   815   833   877   891   925   954   976  1005  1048  1063    1005       1005
# 2         Moncton   469   479   495   504   513   523   531   538   560   561   578   588   611   612   636   643   656   675   691   715   731   742   762   760   798     762        762
# 3      Saint John   429   436   439   437   441   449   452   457   460   483   492   504   520   526   556   570   618   644   645   670   691   691   714   718   720     714        714
# ...

# %%
# Checking the number of rows and columns
rent.shape
# Out:
#          City  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  \
# 0  St. JohnÕs   566   554   559   565   570   567   513   517   552  ...
# 1     Halifax   595   604   610   615   617   616   631   637   648  ...
# 2     Moncton   469   479   495   504   513   523   531   538   560  ...
#
#    2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   614   630   677   725   771   798   864   888   923   958
# 1   815   833   877   891   925   954   976  1005  1048  1063
# 2   643   656   675   691   715   731   742   762   760   798
#
# [3 rows x 26 columns]

# %%
# The df.info() method is great for seeing all the columns in the dataset and it will also give you a quick glance at null values and the data types interger, object for my features.
print(rent.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 26 columns):
# City    34 non-null object
# 1992    34 non-null int64
# 1993    34 non-null int64
# 1994    34 non-null int64
# 1995    34 non-null int64
# 1996    34 non-null int64
# 1997    34 non-null int64
# 1998    34 non-null int64
# 1999    34 non-null int64
# 2000    34 non-null int64
# 2001    34 non-null int64
# 2002    34 non-null int64
# 2003    34 non-null int64
# 2004    34 non-null int64
# 2005    34 non-null int64
# 2006    34 non-null int64
# 2007    34 non-null int64
# 2008    34 non-null int64
# 2009    34 non-null int64
# 2010    34 non-null int64
# 2011    34 non-null int64
# 2012    34 non-null int64
# 2013    34 non-null int64
# 2014    34 non-null int64
# 2015    34 non-null int64
# 2016    34 non-null int64
# dtypes: int64(25), object(1)
# memory usage: 7.0+ KB
# None

# %%
# The rent data set seem to have no missing values there are 34 non null values in the output above.

# %%
# We have to sure we set the data up in order to be used in regression so I am just double checking for null values and this calculation confirms that there are none.
print(rent.isnull().sum().to_string())
# Out:
# City    0
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0

# %% [markdown]
# With no missing values this makes it easier to clean the data.

# %%
# We need to understand the data we use the describe() method to print the summary statistics of the dataframe. 
# The .T is used to swap the rows and columns and transforms it to a table view. 

rent.describe().T
# Out:
#       count        mean         std    min     25%     50%      75%     max
# 1992   34.0  569.147059   92.436426  395.0  504.00   589.0   617.25   771.0
# 1993   34.0  580.470588   97.797637  400.0  506.25   598.0   631.75   790.0
# 1994   34.0  586.882353  102.112168  402.0  506.75   599.5   642.75   812.0
# 1995   34.0  594.676471  105.442422  406.0  514.50   614.5   648.75   826.0
# 1996   34.0  601.500000  107.698021  405.0  514.25   620.0   657.00   845.0
# 1997   34.0  604.382353  106.651802  406.0  523.50   623.5   660.25   852.0
# 1998   34.0  615.970588  115.530000  411.0  526.00   632.0   677.25   881.0
# 1999   34.0  625.705882  120.791463  403.0  535.00   635.5   697.50   916.0
# 2000   34.0  645.058824  132.840743  413.0  549.75   646.5   728.00   979.0
# 2001   34.0  666.676471  140.662657  419.0  569.25   660.0   739.50  1027.0
# 2002   34.0  685.323529  144.182486  431.0  583.00   687.5   768.00  1047.0
# ...

# %%
# Location is one of the most important factors in real estate and the ‘City’ provides some insights. 
# We use the .groupby() method to do this so we can take a quick glance at the Cities mean prices
rent.groupby('City', as_index=True)['1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'].mean()
# Out:
#                                1992  1993  1994  1995  1996  1997  1998  1999  \
# City
# Abbotsford-Mission              615   635   640   651   645   628   633   630
# Barrie                          653   670   687   712   713   737   774   788
# Brantford                       541   572   593   606   610   612   617   614
# Calgary                         598   584   585   584   595   635   707   739
# Edmonton                        544   543   524   519   518   525   551   576
# Gatineau                        513   519   528   536   537   530   529   534
# Greater Sudbury/Grand Sudbury   594   610   610   621   624   619   623   612
# Guelph                          618   626   642   642   658   678   686   702
# Halifax                         595   604   610   615   617   616   631   637
# Hamilton                        574   599   602   614   625   636   662   698
# Kelowna                         586   623   633   634   644   640   638   642
# ...

# %% [markdown]
# We can see the output above and it’s quickly apparent that cities is a major factor in prices.

# %%
# Creating a datafrme to analyze correlation in the rent dataset
explore = rent[['City', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']]
explore.corr()
# Out:
#           1992      1993      1994      1995      1996      1997      1998  \
# 1992  1.000000  0.994219  0.988437  0.986369  0.983369  0.979249  0.961631
# 1993  0.994219  1.000000  0.997154  0.994315  0.991486  0.982883  0.963436
# 1994  0.988437  0.997154  1.000000  0.996927  0.995037  0.986755  0.962693
# 1995  0.986369  0.994315  0.996927  1.000000  0.998173  0.990004  0.966461
# 1996  0.983369  0.991486  0.995037  0.998173  1.000000  0.993777  0.970745
# 1997  0.979249  0.982883  0.986755  0.990004  0.993777  1.000000  0.984318
# 1998  0.961631  0.963436  0.962693  0.966461  0.970745  0.984318  1.000000
# 1999  0.949688  0.948806  0.945173  0.948685  0.953857  0.971569  0.995704
# 2000  0.941705  0.940605  0.936860  0.942233  0.946839  0.962871  0.984445
# 2001  0.932732  0.928920  0.922780  0.926852  0.930484  0.949751  0.976461
# 2002  0.932378  0.926682  0.918013  0.921152  0.924942  0.944214  0.971481
# ...

# %%
# Using Seaborn heatmap to plotting the correlation data to get a better visual of the data
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(explore.corr(), annot = True,linewidths=.4, fmt='.1f', ax=ax)
plt.show()

# %%
# it appares that 1997 and 1998 has the strongest correlation in the data

# %% [markdown]
# # Finding the to 10 hightest and lowest rent prices for 2 bedroom apartments.

# %%
# Using the n.largest I will search the data to find the highest prices for 2 bedroom apartments.
lrg = rent.nlargest(10, ['1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'])
lrg
# Out:
#                   City  1992  1993  1994  1995  1996  1997  1998  1999  2000  \
# 32           Vancouver   771   790   812   826   845   852   870   864   890
# 14             Toronto   754   773   784   805   819   821   881   916   979
# 10              Ottawa   700   727   738   738   739   729   754   783   877
# 33            Victoria   684   703   713   715   717   724   722   728   731
# 22              Barrie   653   670   687   712   713   737   774   788   830
# 13              Oshawa   651   659   659   689   700   691   726   745   778
# 24         Thunder Bay   620   632   655   659   672   666   647   647   654
# 21             Windsor   620   631   643   667   682   680   680   696   736
# 19              Guelph   618   626   642   642   658   678   686   702   736
# 31  Abbotsford-Mission   615   635   640   651   645   628   633   630   632
#
#     ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# ...

# %%
# Above we have the top 10 cities with the highest rent prices.

# %%
# Using Seaborn heatmap to plotting the correlation data to get a better visual on the graph
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(lrg.corr(), annot = True,linewidths=.4, fmt='.1f', ax=ax)
plt.show()

# %%
# What this allows us to do is quickly see which features have the most significant (positive or negative) correlations, and 
# also see which features are unlikely to be that relevant. 
#In the top 10 most expensive cites 2005,2016,2017 and 2018 appears to have the strongest correlation in the data.

# %%
# what I’m doing here is using rent.corr() to get the correlations. I am then turning that information into a dictionary with .to_dict(), 
# while .items() is turning the correlations into key, value pairs necessary for a dictionary. We’re correlating by ‘2014’. 
# We use the lambda expression to order things properly. Finally, we use .sorted() method to sort the values, with the argument ‘reverse=True’,
# so that the highest correlation shows up at the top.
corr_list = sorted(lrg.corr().to_dict()['2005'].items(), key=lambda x: x[1], reverse=True)
corr_list
# Out:
# [('2005', 1.0),
#  ('2006', 0.9933259705302532),
#  ('2004', 0.9916314799409651),
#  ('1999', 0.9863969625196545),
#  ('2002', 0.984590008783648),
#  ('2003', 0.9837683039707742),
#  ('2007', 0.9770540171946238),
#  ('2001', 0.9768019670069784),
#  ('2000', 0.9750500505551026),
#  ('1998', 0.9720021451660987),
#  ('2008', 0.9590964207762317),
#  ('2009', 0.9209838280957241),
#  ('2014', 0.9198763742791685),
#  ('1997', 0.9196465081048639),
#  ('2013', 0.9184450806811817),
#  ('2015', 0.9165755566658365),
#  ('2012', 0.915771554017767),
#  ('2010', 0.9147216897043384),
#  ('2011', 0.9131909606661887),
#  ('2016', 0.8992246290643922),
#  ('1996', 0.8937604932134641),
#  ('1995', 0.892750435501666),
#  ('1992', 0.8873164265603348),
#  ('1993', 0.8730449526351872),
#  ('1994', 0.8605894586664543)]

# %%
#  Johnson distribution

import scipy.stats as st
y = lrg['2005']
plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)
plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)
plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)

# %%
#It is apparent Price doesn't follow normal distribution, so before performing regression it has to be transformed. While log transformation does pretty good job, best fit is unbounded Johnson distribution.

# %%
f = pd.melt(lrg, value_vars=numerical)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %%
#Some independent variables look like good candidates for log transformation.

# %%
# The numeric variables in the dataset
numerical = [
    '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'
]

# %%
df1=lrg[['1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016']]
h = df1.hist(bins=15,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)
sns.despine(left=True, bottom=True)
[x.title.set_size(12) for x in h.ravel()];
[x.yaxis.tick_left() for x in h.ravel()];

# %%
#This is not a very big data and we do not have too many features. Thus, we have chance to plot most of them and reach some useful analytical results. Drawing charts and examining the data before applying a model it a god way to detect possible outliers to decide to do normalization.

# %%
# Price is what we need to predict. So let's do some analysis on this variable first.
from scipy import stats
from scipy.stats import norm, skew #for some statistics

sns.distplot(rent['2006'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(rent['2006'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('RentPrice distribution')

fig = plt.figure()
res = stats.probplot(rent['2006'], plot=plt)
plt.show()
# Out:
#  mu = 750.56 and sigma = 143.06

# %%
## Scatter Plot of the average rent in 2005, 2006 and 2007 using the filtered data for the top 8 cites
lrg.plot(kind='scatter',x = '2005', y = '2006', alpha=0.5, color='b')
plt.xlabel('2005')
plt.ylabel('2006')
plt.title('Average rent in 2005 to 2006')
lrg.plot(kind='scatter',x = '2006', y = '2007', alpha=0.5, color='r')
plt.xlabel('2006')
plt.ylabel('2007')
plt.title('Average rent in 2006 to 2007')
# Out:
# Text(0.5, 1.0, 'Average rent in 2006 to 2007')

# %%
#I choose these 3 years to plot because they have the strongest correlation in the dataset.

# %% [markdown]
# # Here we are filtering the rent dataset to find the top 10 least expensive cities

# %%
# The .nsmallest was used t get the cities with the lowest prices for 2 bedroom apartments
sml = rent.nsmallest(10, ['1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'])
sml
# Out:
#               City  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  \
# 7   Trois-Rivires   395   400   402   406   405   406   411   403   413  ...
# 6      Sherbrooke    408   418   420   422   426   426   433   434   437  ...
# 4         Saguenay   420   419   416   417   423   425   428   428   438  ...
# 3       Saint John   429   436   439   437   441   449   452   457   460  ...
# 27       Saskatoon   444   449   452   460   479   500   516   529   541  ...
# 2          Moncton   469   479   495   504   513   523   531   538   560  ...
# 26          Regina   484   487   485   487   494   512   525   547   549  ...
# 8        Montral    488   484   484   494   491   491   499   506   509  ...
# 5           Qubec   501   502   501   513   511   513   513   511   518  ...
# 9         Gatineau   513   519   528   536   537   530   529   534   544  ...
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# ...

# %%
# The outputs abov shows the 10 least exensive cities to rent apartments

# %%
# Plotting the correlation data to get a better visual on the graph
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(sml.corr(), annot = True,linewidths=.4, fmt='.1f', ax=ax)
plt.show()

# %%
# In the above plot it shows that 2007 has the strongest correlation

# %%
# Detect Outliers in the sml (least expensive data) 
sns.boxplot(data=sml)

# %%
# There seem to be few outliers in the data which we would have to take a closer look at.

# %%
# Looking for outliers in the lrg ( most expensive data)
sns.boxplot(data=lrg)

# %%
# There seem to be few outliers in the data which we would have to take a closer look at.

# %%
# Below is 1996 one of the year that appares to have outliers
sns.boxplot(lrg['1996'])

# %%
# Below we have 1997 one of the year which appears to have outliers
sns.boxplot(lrg['1997'])

# %%
from numpy import mean
from numpy import std
print(mean(rent),
      std(rent))
# Out:
# 1992    569.147059
# 1993    580.470588
# 1994    586.882353
# 1995    594.676471
# 1996    601.500000
# 1997    604.382353
# 1998    615.970588
# 1999    625.705882
# 2000    645.058824
# 2001    666.676471
# 2002    685.323529
# 2003    701.147059
# 2004    715.088235
# 2005    727.588235
# 2006    750.558824
# 2007    776.500000
# 2008    809.647059
# 2009    826.764706
# 2010    842.176471
# 2011    866.294118
# 2012    890.352941
# 2013    915.647059
# 2014    944.529412
# 2015    968.529412
# 2016    993.529412
# dtype: float64 1992     91.066922
# 1993     96.348703
# 1994    100.599311
# 1995    103.880225
# 1996    106.102406
# 1997    105.071688
# 1998    113.818350
# 1999    119.001861
# 2000    130.872624
# 2001    138.578651
# 2002    142.046331
# 2003    141.918189
# 2004    139.300641
# 2005    137.086516
# 2006    143.059879
# 2007    154.270437
# 2008    162.395465
# 2009    158.609965
# 2010    156.626470
# 2011    160.665075
# 2012    169.433638
# ...

# %%
def get_median_filtered(signal, threshold=3):
    signal = signal.copy()
    difference = np.abs(signal - np.median(signal))
    median_difference = np.median(difference)
    if median_difference == 0:
        s = 0
    else:
        s = difference / float(median_difference)
    mask = s > threshold
    signal[mask] = np.median(signal)
    return signal

# %%
outliers=[]
def detect_outlier(lrg):

    threshold=3
    mean_1 = np.mean(lrg)
    std_1 =np.std(lrg)
    
    
    for y in lrg:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
outliers=[]
def detect_outlier(lrg):
    
    threshold=3
    mean_1 = np.mean(lrg)
    std_1 =np.std(lrg)

# %%
outlier_datapoints = detect_outlier(rent)
print(outlier_datapoints)
# Out:
# None

# %%
fig, ax = plt.subplots(1,2)
sns.regplot('2005','2006',lrg, ax=ax[0], scatter_kws={'alpha':0.4})
sns.regplot('2006','2007',lrg,ax=ax[1], scatter_kws={'alpha':0.4})

# %%
#The line of best fit is calculated by minimizing the ordinary least squares error function, that Seaborn module does automatically using the regplot function.
#The shaded area around the line represents 95% confidence intervals.

# %%
#To visualize the residuals in each case, Seaborn can also be used to create residual plot .
fig, ax = plt.subplots(1,2)
ax[0]= sns.residplot('2005','2006', lrg,ax=ax[0], scatter_kws={'alpha':0.4})
ax[0].set_ylabel('2005 residual')
ax[1]=sns.residplot('2006','2007',lrg,ax=ax[1], scatter_kws={'alpha':0.4})
ax[1].set_ylabel('2006 residual')
# Out:
# Text(0, 0.5, '2006 residual')

# %%
# The points in the residual plot represent the difference between the sample (y) and the predicted value (y’). 
#Residuals that are greater than zero are points that are underestimated by the model and residuals less than zero are points that are overestimated by the model.

# %%
# Next we’ll want to fit a linear regression model. We need to choose variables that we think we’ll be good predictors for the dependent variable.
# This can be done by checking the correlation(s) between variables, on what variables are good predictors of y.

import statsmodels.api as sm

X = lrg["2005"]
y = lrg["2006"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# C:\Users\susie\Anaconda3\lib\site-packages\scipy\stats\stats.py:1416: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   2006   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.538e+04
# Date:                Tue, 06 Aug 2019   Prob (F-statistic):           1.73e-17
# Time:                        00:23:36   Log-Likelihood:                -40.606
# No. Observations:                  10   AIC:                             83.21
# Df Residuals:                       9   BIC:                             83.51
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
# OLS stands for Ordinary Least Squares and the method “Least Squares” means that we’re trying to fit a regression line that
# would minimize the square of distance from the regression line.

# %%
X = lrg["2005"] ## X usually means our input variables (or independent variables)
y = lrg["2006"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# C:\Users\susie\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# C:\Users\susie\Anaconda3\lib\site-packages\scipy\stats\stats.py:1416: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   2006   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     593.3
# Date:                Tue, 06 Aug 2019   Prob (F-statistic):           8.61e-09
# Time:                        00:24:19   Log-Likelihood:                -40.292
# No. Observations:                  10   AIC:                             84.58
# ...

# %%
#  With the constant term the coefficients are different. Without a constant we are forcing our model to go through the origin,
#but now we have a y-intercept at -26.67. We also changed the slope of the 2005 predictor from 1.0171 to 1.0478.

# %%
# Loading the income after tax dataset
income= pd.read_csv(r"C:\\Users\\susie\\Documents\\Data Science\\Capstone data\\Average income.csv"
                   ,encoding="latin1")
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 13 columns):
# Cities    29 non-null object
# 2006      29 non-null int64
# 2007      29 non-null int64
# 2008      29 non-null int64
# 2009      29 non-null int64
# 2010      29 non-null int64
# 2011      29 non-null int64
# 2012      29 non-null int64
# 2013      29 non-null int64
# 2014      29 non-null int64
# 2015      29 non-null int64
# 2016      29 non-null int64
# 2017      29 non-null int64
# dtypes: int64(12), object(1)
# memory usage: 3.0+ KB

# %%
# Taking a peek at the data, by using the df.head() functiononly returns the first five rows because there are 13 columns we are unable to see all of them.
print(income.head())
# Out:
#          Cities   2006   2007   2008   2009   2010   2011   2012   2013  \
# 0     St John's  34400  33000  38000  38300  40000  42300  42900  48400
# 1       Halifax  40100  43400  39200  41300  43200  48100  45100  47600
# 2    Saint John  38600  41900  41700  43000  42500  40400  30200  43000
# 3      Saguenay  31600  33100  33800  34100  35400  38400  37000  38200
# 4  Quebec - CMA  38100  38000  42100  43500  40800  43700  43500  47000
#
#     2014   2015   2016   2017
# 0  49500  48300  45700  43400
# 1  44400  43900  44800  46500
# 2  39400  39900  43200  40600
# 3  33000  35400  37800  35100
# 4  44100  38500  40900  44600

# %%
# The .to_string() method give a much better view of the data contents and I have selecting 10 rows to view

print(income.head(20).to_string())
# Out:
#                          Cities   2006   2007   2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# 0                     St John's  34400  33000  38000  38300  40000  42300  42900  48400  49500  48300  45700  43400
# 1                       Halifax  40100  43400  39200  41300  43200  48100  45100  47600  44400  43900  44800  46500
# 2                    Saint John  38600  41900  41700  43000  42500  40400  30200  43000  39400  39900  43200  40600
# 3                      Saguenay  31600  33100  33800  34100  35400  38400  37000  38200  33000  35400  37800  35100
# 4                  Quebec - CMA  38100  38000  42100  43500  40800  43700  43500  47000  44100  38500  40900  44600
# 5                    Sherbrooke  32900  34800  36100  35400  36600  34100  32600  35300  36200  41500  37700  35800
# 6                Trois-Rivières  28700  36800  35800  36500  34800  34300  31300  34100  33600  31800  38500  36200
# ...

# %%
# Checking the shape of the data which outputs 40 rows and 13 columns
income.shape
# Out:
# (29, 13)

# %%
# The df.info() method is great for seeing all the columns in the dataset and it will also give you a quick glance at null values and the data types  float, object for my features.
print(income.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 13 columns):
# Cities    29 non-null object
# 2006      29 non-null int64
# 2007      29 non-null int64
# 2008      29 non-null int64
# 2009      29 non-null int64
# 2010      29 non-null int64
# 2011      29 non-null int64
# 2012      29 non-null int64
# 2013      29 non-null int64
# 2014      29 non-null int64
# 2015      29 non-null int64
# 2016      29 non-null int64
# 2017      29 non-null int64
# dtypes: int64(12), object(1)
# memory usage: 3.0+ KB
# None

# %% [markdown]
# As you can see above all features have 29 total entries and 29 non-null entries we have no missing entries.

# %%
# We have to make sure we set the data up in order to be used in regression so I am double check for null values.
print(rent.isnull().sum().to_string())
# Out:
# City    0
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0

# %% [markdown]
# The above code sums up the null values and they all output to zero

# %%
# We need to understand the data we use the describe() method to print the summary statistics of the dataframe. 
# The .T is used to swap the rows and columns and transforms it to a table view. 

income.describe().T
# Out:
#       count          mean          std      min      25%      50%      75%  \
# 2006   29.0  41403.448276  6259.819872  28700.0  37700.0  40100.0  45600.0
# 2007   29.0  43389.655172  7047.408076  33000.0  38900.0  42800.0  45700.0
# 2008   29.0  43162.068966  7647.427849  33800.0  38000.0  42100.0  46100.0
# 2009   29.0  43741.379310  7677.449225  34100.0  38300.0  42200.0  45800.0
# 2010   29.0  43400.000000  7522.110266  34800.0  38600.0  42500.0  46000.0
# 2011   29.0  44868.965517  7335.778440  30700.0  40400.0  45100.0  48100.0
# 2012   29.0  44355.172414  7761.562168  30200.0  41000.0  43500.0  47200.0
# 2013   29.0  45817.241379  7712.840359  34100.0  40800.0  44900.0  49200.0
# 2014   29.0  45958.620690  9236.322600  33000.0  39400.0  44100.0  51300.0
# 2015   29.0  46472.413793  8702.130140  31800.0  41500.0  46800.0  49900.0
# 2016   29.0  48241.379310  9229.824222  33600.0  42000.0  45700.0  54500.0
# ...

# %%
# For our data types Cities column is an object and all other columns are int which is what we want to see. There isn't much cleaning to be done with ut data
income.dtypes
# Out:
# Cities    object
# 2006       int64
# 2007       int64
# 2008       int64
# 2009       int64
# 2010       int64
# 2011       int64
# 2012       int64
# 2013       int64
# 2014       int64
# 2015       int64
# 2016       int64
# 2017       int64
# dtype: object

# %%
income.columns
# Out:
# Index(['Cities', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
# Cities provides insight into this averge income and seem to have a big factor on income rates. 
# We use the .groupby() method to do this so we can take a quick glance at the Cities mean income'
income.groupby('Cities', as_index=True)['2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017'].mean()
# Out:
#                               2006   2007   2008   2009   2010   2011   2012  \
# Cities
# Abbotsford                   49200  44000  42100  47700  42500  47000  53100
# Calgary                      58000  65800  71000  61800  61700  63200  67300
# Edmonton                     50100  58400  56900  66800  65800  58600  57900
# Greater Sudbury              39200  39900  41700  39300  38100  45000  44700
# Halifax                      40100  43400  39200  41300  43200  48100  45100
# Hamilton                     43800  43800  45700  43000  46000  41600  42900
# Kingston                     37800  42800  44500  37800  37500  46500  47100
# Kitchener                    45800  50800  46100  50800  42900  45100  40200
# London                       44400  42800  36300  38000  34800  30700  41600
# Montreal                     40400  41200  42400  41100  40400  42900  41000
# Oshawa                       44600  38200  37400  39700  42800  39700  47200
# ...

# %% [markdown]
# We can see the output above and it’s quickly apparent that Cities is a major factor on the salary.

# %%
# # Creating a datafrme to analyze correlation in the income dataset
explore1 = income[['2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017']]
explore1.corr()
# Out:
#           2006      2007      2008      2009      2010      2011      2012  \
# 2006  1.000000  0.856972  0.788393  0.783632  0.636435  0.657355  0.695354
# 2007  0.856972  1.000000  0.924914  0.889853  0.800866  0.785016  0.724085
# 2008  0.788393  0.924914  1.000000  0.881961  0.821422  0.823618  0.741290
# 2009  0.783632  0.889853  0.881961  1.000000  0.901005  0.813144  0.680635
# 2010  0.636435  0.800866  0.821422  0.901005  1.000000  0.779448  0.753958
# 2011  0.657355  0.785016  0.823618  0.813144  0.779448  1.000000  0.755069
# 2012  0.695354  0.724085  0.741290  0.680635  0.753958  0.755069  1.000000
# 2013  0.705201  0.836171  0.882094  0.842246  0.876180  0.829863  0.818140
# 2014  0.639500  0.753722  0.781697  0.846690  0.858151  0.817730  0.832601
# 2015  0.663611  0.760415  0.749062  0.852807  0.903273  0.762029  0.750370
# 2016  0.686831  0.783229  0.794138  0.874442  0.831280  0.828932  0.672003
# ...

# %%
# Here is a better visual on the correlation graph 
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(explore1.corr(), annot = True,linewidths=.4, fmt='.1f', ax=ax)
plt.show()

# %%
# From the visual above it seem like 2009 and 2015 has the strongest correlation in the income dataset

# %% [markdown]
# # Finding the hightest and lowest income ranges for top 10 cities.

# %%
# Using the n.largest I will search the data to find cities with the highest income.
high = income.nlargest(10, ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017'])
high
# Out:
#                          Cities   2006   2007   2008   2009   2010   2011  \
# 24                      Calgary  58000  65800  71000  61800  61700  63200
# 25                     Edmonton  50100  58400  56900  66800  65800  58600
# 26                   Abbotsford  49200  44000  42100  47700  42500  47000
# 28                     Victoria  47400  47300  47200  45300  38900  52900
# 27                    Vancouver  46600  50600  47800  45800  49000  47300
# 10   Ottawa - Gatineau (Québec)  46400  44800  42100  42200  38600  46600
# 16                    Kitchener  45800  50800  46100  50800  42900  45100
# 13                      Toronto  45600  45700  50200  51900  51100  46200
# 8             Ottawa - Gatineau  45400  48100  49100  50900  48400  51100
# 9   Ottawa - Gatineau (Ontario)  45000  49200  50900  53100  50600  52600
#
#      2012   2013   2014   2015   2016   2017
# 24  67300  70000  66500  63900  63400  66700
# 25  57900  61800  67800  72200  66800  66200
# ...

# %%
# Using Seaborn heatmap to plotting the correlation data to get a better visual on the graph
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(high.corr(), annot = True,linewidths=.4, fmt='.1f', ax=ax)
plt.show()

# %%
# This allows us to quickly see which features have the most significant (positive or negative) correlations, 
# and also see which features are unlikely to be that relevant. For this dataset, I find that 2007,2008 and 2010 are the highest correlated features.

# %%
import scipy.stats as st
y = high['2007']
plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)
plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)
plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)

# %%
#It is apparent that income doesn't follow normal distribution, so before performing regression it has to be transformed. Best fit is unbounded Johnson distribution.

# %%
numeric =['2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017']

# %%
f = pd.melt(high, value_vars=numeric)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %%
#Some independent variables look like good candidates for log transformation.

# %%
df2=high[['2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017']]
h = df2.hist(bins=15,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)
sns.despine(left=True, bottom=True)
[x.title.set_size(12) for x in h.ravel()];
[x.yaxis.tick_left() for x in h.ravel()];

# %%
#This is not a very big data and we do not have too many features. Thus, we have chance to plot most of them and reach some useful analytical results. Drawing charts and examining the data before applying a model we can detect some possible outliers or decide to do normalization.

# %%
# Income is what we need to predict. So let's do some analysis on this variable first.

sns.distplot(rent['2007'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(high['2007'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Income distribution')

fig = plt.figure()
res = stats.probplot(high['2007'], plot=plt)
plt.show()
# Out:
#  mu = 50470.00 and sigma = 6419.20

# %% [markdown]
# # Filtering the data to find the cities with the lowest income

# %%
# Using the n.largest I will search the data to find cities with the highest income.
low = income.nsmallest(10, ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017'])
low
# Out:
#             Cities   2006   2007   2008   2009   2010   2011   2012   2013  \
# 6   Trois-Rivières  28700  36800  35800  36500  34800  34300  31300  34100
# 3         Saguenay  31600  33100  33800  34100  35400  38400  37000  38200
# 5       Sherbrooke  32900  34800  36100  35400  36600  34100  32600  35300
# 0        St John's  34400  33000  38000  38300  40000  42300  42900  48400
# 22          Regina  36000  44000  43700  44100  53400  51600  53300  53900
# 20     Thunder Bay  37100  38900  35000  39400  42800  36800  40500  39000
# 21        Winnipeg  37200  40400  38100  37600  39300  42900  42100  42800
# 18         Windsor  37700  38700  38500  34300  35600  34600  42100  35200
# 11        Kingston  37800  42800  44500  37800  37500  46500  47100  44800
# 4     Quebec - CMA  38100  38000  42100  43500  40800  43700  43500  47000
#
#      2014   2015   2016   2017
# 6   33600  31800  38500  36200
# 3   33000  35400  37800  35100
# 5   36200  41500  37700  35800
# ...

# %%
features1 = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017']

mask = np.zeros_like(low[features1].corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation Matrix',fontsize=25)

sns.heatmap(low[features1].corr(),linewidths=0.25,vmax=0.7,square=True,cmap="BuGn", #"BuGn_r" to reverse 
            linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": .9});

# %%
# Above it apares 2012 and 2017 has the strongest correlation

# %%
## Scatter Plot of the average rent in 2006, 2007 and 2017 using the filtered data for the top 9 cites
low.plot(kind='scatter',x = '2011', y = '2012', alpha=0.5, color='b')
plt.xlabel('2011')
plt.ylabel('2012')
plt.title('Average income in 2011 to 2012')
lrg.plot(kind='scatter',x = '2015', y = '2016', alpha=0.5, color='r')
plt.xlabel('2016')
plt.ylabel('2017')
plt.title('Average income in 2015 to 2016')
# Out:
# Text(0.5, 1.0, 'Average income in 2016 to 2017')

# %%
# It appears something went wrong I would have to take some time to figure out why 2011 has just few data points

# %%
# Detect Outliers for the cities with the lowest income
sns.boxplot(data=low)

# %%
# Detect Outliers for cities with the highest income
sns.boxplot(data=high)

# %%
# Both the High and Low income dataframes has outliers he needs to be taken care of.

# %%
fig, ax = plt.subplots(1,2)
sns.regplot('2007','2008',high, ax=ax[0], scatter_kws={'alpha':0.4})
sns.regplot('2009','2010',high,ax=ax[1], scatter_kws={'alpha':0.4})

# %%
#The line of best fit is calculated by minimizing the ordinary least squares error function, that Seaborn module does automatically using the regplot function.
#The shaded area around the line represents 95% confidence intervals.

# %%
#To visualize the residuals in each case, Seaborn can also be used to create residual plot .
fig, ax = plt.subplots(1,2)
ax[0]= sns.residplot('2007','2008', high,ax=ax[0], scatter_kws={'alpha':0.4})
ax[0].set_ylabel('2007 residual')
ax[1]=sns.residplot('2009','2010',high,ax=ax[1], scatter_kws={'alpha':0.4})
ax[1].set_ylabel('2009 residual')
# Out:
# Text(0, 0.5, '2009 residual')

# %%
# The points in the residual plot represent the difference between the sample (y) and the predicted value (y’). 
#Residuals that are greater than zero are points that are underestimated by the model and residuals less than zero are points that are overestimated by the model.

# %%
# Next we’ll want to fit a linear regression model. We need to choose variables that we think we’ll be good predictors for the dependent variable.
# This can be done by checking the correlation(s) between variables, on what variables are good predictors of y.

import statsmodels.api as sm

X = high["2007"]
y = high["2009"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# C:\Users\susie\Anaconda3\lib\site-packages\scipy\stats\stats.py:1416: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   2009   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     1320.
# Date:                Tue, 06 Aug 2019   Prob (F-statistic):           4.49e-11
# Time:                        01:08:29   Log-Likelihood:                -97.829
# No. Observations:                  10   AIC:                             197.7
# Df Residuals:                       9   BIC:                             198.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
# OLS stands for Ordinary Least Squares and the method “Least Squares” means that we’re trying to fit a regression line that
# would minimize the square of distance from the regression line.

# %%
X = high["2007"] ## X usually means our input variables (or independent variables)
y = high["2009"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# C:\Users\susie\Anaconda3\lib\site-packages\scipy\stats\stats.py:1416: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   2009   R-squared:                       0.654
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     15.12
# Date:                Tue, 06 Aug 2019   Prob (F-statistic):            0.00462
# Time:                        01:09:35   Log-Likelihood:                -97.672
# No. Observations:                  10   AIC:                             199.3
# Df Residuals:                       8   BIC:                             199.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
#  With the constant term the coefficients are different. Without a constant we are forcing our model to go through the origin,
#but now we have a y-intercept at -34.67. We also changed the slope of the 2007 predictor from 1.0211 to 0.9045.

# %%
# Looking for outliers in the high income data
sns.boxplot(data=high)

# %%
# There seem to be few outliers in the data which we would have to take a closer look at.

# %%
# Looking for outliers in the low income 
sns.boxplot(data=low)

# %%
# There seem to be outliers in both the top 10 highest and lowest data which we would have to take a closer look at.

# %%
# Loading the monthly debt payments
market= pd.read_csv(r"C:\\Users\\susie\\Documents\\Data Science\\Capstone data\\Housing market indicators.csv"
                   ,encoding="latin1")
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 28 columns):
# Indicators    35 non-null object
# 1990          26 non-null float64
# 1991          27 non-null float64
# 1992          31 non-null float64
# 1993          31 non-null float64
# 1994          31 non-null float64
# 1995          31 non-null float64
# 1996          31 non-null float64
# 1997          31 non-null float64
# 1998          32 non-null float64
# 1999          32 non-null float64
# 2000          32 non-null float64
# 2001          32 non-null float64
# 2002          32 non-null float64
# 2003          32 non-null float64
# 2004          32 non-null float64
# 2005          33 non-null float64
# 2006          33 non-null float64
# 2007          33 non-null float64
# 2008          33 non-null float64
# 2009          34 non-null float64
# 2010          34 non-null float64
# 2011          34 non-null float64
# 2012          34 non-null float64
# ...

# %%
# Taking a peek at the data the rent.head function only returns the first five rows because there are 26 columns we are unable to see all of them.
print(market.head())
# Out:
#         Indicators     1990     1991     1992     1993     1994     1995  \
# 0  Single-detached  32425.0  26290.0  27868.0  26240.0  30036.0  20124.0
# 1         Multiple  30224.0  26504.0  27904.0  18900.0  16609.0  15694.0
# 2    Semi-detached   2338.0   1730.0   2611.0   2537.0   3421.0   2306.0
# 3              Row   8462.0   9472.0   9246.0   7448.0   7226.0   6175.0
# 4        Apartment  19424.0  15302.0  16047.0   8915.0   5962.0   7213.0
#
#       1996     1997     1998  ...     2007     2008     2009     2010  \
# 0  27019.0  35401.0  32737.0  ...  37910.0  31108.0  22634.0  28089.0
# 1  16043.0  18671.0  21093.0  ...  30213.0  43968.0  27736.0  32344.0
# 2   3348.0   4299.0   4575.0  ...   4284.0   3415.0   3007.0   3006.0
# 3   8124.0   9964.0  10073.0  ...  11255.0  11212.0   7121.0  10255.0
# 4   4571.0   4408.0   6445.0  ...  14674.0  29341.0  17608.0  19083.0
#
#       2011     2012     2013     2014     2015     2016
# ...

# %%
# The .to_string() method give a much better view of the data contents and I have selecting 10 rows to view
print(market.head(10).to_string())
# Out:
#                         Indicators     1990     1991     1992     1993     1994     1995     1996     1997     1998     1999     2000     2001     2002     2003     2004     2005     2006     2007     2008     2009     2010     2011     2012     2013     2014     2015     2016
# 0                  Single-detached  32425.0  26290.0  27868.0  26240.0  30036.0  20124.0  27019.0  35401.0  32737.0  39421.0  41087.0  39632.0  51114.0  47610.0  48929.0  41682.0  38309.0  37910.0  31108.0  22634.0  28089.0  26884.0  25567.0  23270.0  23691.0  24953.0  30079.0
# 1                         Multiple  30224.0  26504.0  27904.0  18900.0  16609.0  15694.0  16043.0  18671.0  21093.0  27814.0  30434.0  33650.0  32483.0  37570.0  36185.0  37113.0  35108.0  30213.0  43968.0  27736.0  32344.0  40937.0  51175.0  37815.0  35443.0  45203.0  44873.0
# ...

# %%
# Checking the number of rows and columns
market.shape
# Out:
# (35, 28)

# %%
# We need to understand the data we use the describe() method to print the summary statistics of the dataframe. 
# The .T is used to swap the rows and columns and transforms it to a table view. 

market.describe().T
# Out:
#       count          mean           std        min        25%     50%  \
# 1990   26.0  13872.265317  21689.977636  -1.329857  22.360093  1991.0
# 1991   27.0  11496.218729  18022.641527 -10.702960   7.068196  1730.0
# 1992   31.0  13009.038903  20580.247940  -3.211009  39.075000  2798.0
# 1993   31.0  10380.929234  16424.070787  -1.712276  38.791667  2537.0
# 1994   31.0  11094.441789  18614.905572  -1.386121  37.758333  2301.0
# 1995   31.0   9368.513329  16369.285165  -0.015598  37.087500  2219.0
# 1996   31.0  10611.117830  18527.243940  -1.014041  37.270833  1410.0
# 1997   31.0  13009.663802  22791.380660  -0.776114   6.012529  1295.0
# 1998   32.0  12439.892793  21728.869780   0.000000   4.283689  1290.5
# 1999   32.0  14800.047681  24955.166630   1.280444   5.630790  1371.5
# 2000   32.0  16698.039550  30087.066713   1.502962   5.455166  1613.5
# 2001   32.0  18571.479837  35747.730728   1.507853   5.571451  1530.5
# ...

# %%
# The df.info() method is great for seeing all the columns in the dataset and it will also give you a quick glance at null values and the data types  float, object for my features.
print(market.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 28 columns):
# Indicators    35 non-null object
# 1990          26 non-null float64
# 1991          27 non-null float64
# 1992          31 non-null float64
# 1993          31 non-null float64
# 1994          31 non-null float64
# 1995          31 non-null float64
# 1996          31 non-null float64
# 1997          31 non-null float64
# 1998          32 non-null float64
# 1999          32 non-null float64
# 2000          32 non-null float64
# 2001          32 non-null float64
# 2002          32 non-null float64
# 2003          32 non-null float64
# 2004          32 non-null float64
# 2005          33 non-null float64
# 2006          33 non-null float64
# 2007          33 non-null float64
# 2008          33 non-null float64
# 2009          34 non-null float64
# 2010          34 non-null float64
# 2011          34 non-null float64
# 2012          34 non-null float64
# ...

# %% [markdown]
# As you can see above all features have 36 total entries and only the Indicators column has no non-null entries there are fer non null entries in all the other columns.

# %%
# We have to sure we set the data up in order to be used in regression we’ll also need to deal with the null values.
# lets take a look at the null values
print(market.isnull().sum().to_string())
# Out:
# Indicators    0
# 1990          9
# 1991          8
# 1992          4
# 1993          4
# 1994          4
# 1995          4
# 1996          4
# 1997          4
# 1998          3
# 1999          3
# 2000          3
# 2001          3
# 2002          3
# 2003          3
# 2004          3
# 2005          2
# 2006          2
# 2007          2
# 2008          2
# 2009          1
# 2010          1
# 2011          1
# 2012          1
# 2013          1
# 2014          1
# 2015          1
# 2016          2

# %% [markdown]
# As you can see only one of the column has 0 null 1900 and 1980 has the most null values.

# %%
# Here we have a visual of the missing data
missing = market.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
# We will take a closer look at the missing values

# %%
#Before we transform, we should explore these variables a bit. For some features, there is a clear order 
#(e.g. a ‘quality’ variable that has ‘Excellent’, ‘Good’, ‘Fair’ and ‘Poor’ as the possible values).

# %%
market.groupby('Indicators', as_index=True)['1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'].mean()
# Out:
#                                                          1990          1991  \
# Indicators
#   Homeownership  condominium                     11435.000000   4240.000000
#   Homeownership freehold                         28104.000000  24813.000000
#   Other co-op and unknown                         1644.000000   2551.000000
#   Rental                                         12158.000000  14519.000000
#  Semi-detached                                    2338.000000   1730.000000
# 3+ bedroom                                         757.000000    799.000000
# Apartment                                        19424.000000  15302.000000
# Bachelor                                           417.000000    443.000000
# Completions total                                80562.000000  59622.000000
# Construction Wage Rate Index % change                     NaN           NaN
# Consumer Price Index % change                        4.815267      4.636393
# ...

# %%
market.columns

# %%
# We are also going to use median, as well, since there might be some outliers that skew the data.
market.groupby('Indicators', as_index=True)['1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'].median()
# Out:
#                                                          1991          1992  \
# Indicators
#   Homeownership  condominium                      4240.000000   2798.000000
#   Homeownership freehold                         24813.000000  27917.000000
#   Other co-op and unknown                         2551.000000   4180.000000
#   Rental                                         14519.000000  13798.000000
#  Semi-detached                                    1730.000000   2611.000000
# 3+ bedroom                                         799.000000    825.000000
# Apartment                                        15302.000000  16047.000000
# Bachelor                                           443.000000    456.000000
# Completions total                                59622.000000  63134.000000
# Construction Wage Rate Index % change                     NaN           NaN
# Consumer Price Index % change                        4.636393      1.021750
# ...

# %%
# We can see the output above and it’s quickly apparent that indicators is a major factor in the values.

# %%
## # Creating a datafrme to analyze correlation in the market indicator dataset
explore2 = market[['1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016']]
explore2.corr()
# Out:
#           1990      1991      1992      1993      1994      1995      1996  \
# 1990  1.000000  0.988109  0.991970  0.986360  0.963682  0.971028  0.945971
# 1991  0.988109  1.000000  0.995820  0.989564  0.971815  0.980382  0.958865
# 1992  0.991970  0.995820  1.000000  0.993907  0.981646  0.961467  0.963217
# 1993  0.986360  0.989564  0.993907  1.000000  0.989532  0.955807  0.967463
# 1994  0.963682  0.971815  0.981646  0.989532  1.000000  0.981135  0.992631
# 1995  0.971028  0.980382  0.961467  0.955807  0.981135  1.000000  0.993680
# 1996  0.945971  0.958865  0.963217  0.967463  0.992631  0.993680  1.000000
# 1997  0.939518  0.953319  0.964443  0.973352  0.995418  0.985444  0.997896
# 1998  0.941453  0.956939  0.966951  0.974044  0.994385  0.985501  0.997292
# 1999  0.946818  0.959274  0.971373  0.981688  0.991650  0.967370  0.985418
# 2000  0.952078  0.959304  0.962161  0.961195  0.986988  0.993444  0.996997
# ...

# %%
# Plotting the correlation data to get a better visual on the graph
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(explore2.corr(), annot = True,linewidths=.4, fmt='.1f', ax=ax)
plt.show()

# %% [markdown]
# # Finding the to 10 market indicators.

# %%
# Using the n.largest I will search the data to find the top 10 indicators that affects houssing cost.
top = market.nlargest(10, ['1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
top
# Out:
#                           Indicators       1990       1991       1992  \
# 11      Residential Building Permits  61578.000  60093.000  54272.000
# 10                 Completions total  80562.000  59622.000  63134.000
# 5    Starts by intended market total  53341.000  46123.000  48693.000
# 1                           Multiple  30224.000  26504.000  27904.000
# 0                    Single-detached  32425.000  26290.000  27868.000
# 6             Homeownership freehold  28104.000  24813.000  27917.000
# 4                          Apartment  19424.000  15302.000  16047.000
# 7                             Rental  12158.000  14519.000  13798.000
# 29  Population on July 1 (thousands)  10295.832  10431.316  10572.205
# 3                                Row   8462.000   9472.000   9246.000
#
#          1993       1994       1995       1996       1997       1998  ...  \
# 11  45480.000  49404.000  38610.000  46437.000  61070.000  59675.000  ...
# ...

# %%
# Using Seaborn heatmap to plotting the correlation data to get a better visual on the graph
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(top.corr(), annot = True,linewidths=.4, fmt='.1f', ax=ax)
plt.show()

# %%
# What this allows us to do is quickly see which features have the most significant (positive or negative) correlations, 
#and also see which features are unlikely to be that relevant. For this dataset, I find that 2005,2006,2009 and 2010 seem to be the most correlated features.

# %%
import scipy.stats as st
y = top['2009']
plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)
plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)
plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)

# %%
#It is apparent that market indicator doesn't follow normal distribution, so before performing regression it has to be transformed. While log transformation does pretty good job, best fit is unbounded Johnson distribution.

# %%
Features =['1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016']

# %%
f = pd.melt(top, value_vars=Features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %%
#Some independent variables look like good candidates for log transformation.

# %%
#What this allows us to do is quickly see which features have the most significant (positive or negative) correlations, and also see which features are unlikely to be that relevant. For this dataset, I find that 2014, overall quality, 2013 and 2015 are the most correlated features with City.

# %%
# histogram of the top 10 housing indicators
sns.distplot(lrg['2010']);

# %%
df2=top[['1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016']]
h = df2.hist(bins=15,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)
sns.despine(left=True, bottom=True)
[x.title.set_size(12) for x in h.ravel()];
[x.yaxis.tick_left() for x in h.ravel()];

# %%
#This is not a very big data and we do not have too many features. Thus, we have chance to plot most of them and reach some useful analytical results. Drawing charts and examining the data before applying a model we may detect some possible outliers or decide to do normalization.

# %%
y = top['2005'].values
def johnson(y):
    gamma, eta, epsilon, lbda = stats.johnsonsu.fit(y)
    yt = gamma + eta*np.arcsinh((y-epsilon)/lbda)
    return yt, gamma, eta, epsilon, lbda

def johnson_inverse(y, gamma, eta, epsilon, lbda):
    return lbda*np.sinh((y-gamma)/eta) + epsilon

yt, g, et, ep, l = johnson(y)
yt2 = johnson_inverse(yt, g, et, ep, l)
plt.figure(1)
sns.distplot(yt)
plt.figure(2)
sns.distplot(yt2)

# %%
#Here is Johnson Transform of market indicators. I tried Box Cox, Fisher and Johnson transforms but none of these can beat log in simple linear regression. It is probably because they have tunable parameters that overfit to training data.

# %%
# Price is what we need to predict. So let's do some analysis on this variable first.

sns.distplot(top['2006'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(top['2006'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('MarketIndicators distribution')

fig = plt.figure()
res = stats.probplot(rent['2016'], plot=plt)
plt.show()
# Out:
#  mu = 38042.26 and sigma = 25117.37

# %%
## Scatter Plot of the top 10 housing indicators
top.plot(kind='scatter',x = '2005', y = '2006', alpha=0.5, color='b')
plt.xlabel('2005')
plt.ylabel('2006')
plt.title('Top 10 housing indicators 2005 to 2006')
top.plot(kind='scatter',x = '2009', y = '2010', alpha=0.5, color='r')
plt.xlabel('2009')
plt.ylabel('2010')
plt.title('Top 10 housing indicators 2009 to 2010')
# Out:
# Text(0.5, 1.0, 'Top 10 housing indicators 2009 to 2010')

# %%
## With these 2 plots it gives us a shape of the data and tells us it's good for regression.

# %% [markdown]
# # Low market indicators

# %%
# Using the n.smallest I will search the data to find the top 10 indicators that affects houssing cost.
low = market.nsmallest(10, ['1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
low
# Out:
#                              Indicators        1990        1991        1992  \
# 19     New Housing Price Index % change   -1.329857  -10.702960   -3.211009
# 31                Employment (% change)   -0.093768   -3.409135   -1.678440
# 33      Real disposable income % change         NaN   -0.921359    1.951686
# 22   Owned accommodation costs % change    6.632902    2.109974   -0.429377
# 16                Rental vacancy rate %    1.400000    2.200000    2.600000
# 23  Rental accommodation costs % change    3.985029    3.419437    2.917392
# 20        Consumer Price Index % change    4.815267    4.636393    1.021750
# 32                  Unemployment rate %    6.200000    9.500000   10.800000
# 30    Labour force participation rate %   69.541667   68.533333   67.350000
# 24                             Bachelor  417.000000  443.000000  456.000000
#
#           1993        1994        1995        1996        1997        1998  \
# ...

# %%
features2 = ['1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016']

mask = np.zeros_like(low[features2].corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation Matrix',fontsize=25)

sns.heatmap(low[features2].corr(),linewidths=0.25,vmax=0.7,square=True,cmap="BuGn", #"BuGn_r" to reverse 
            linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": .9});

# %%
# I am not liking what I'm seeing from this plot so I will use a differnt correlation plot to get better results

# %%
# Detect Outliers in the top 10 housing indicators data
sns.boxplot(data=top)

# %%
# Detect Outliers in the bottom 10 housing indicators
sns.boxplot(data=low)

# %%
fig, ax = plt.subplots(1,2)
sns.regplot('2005','2006',top, ax=ax[0], scatter_kws={'alpha':0.4})
sns.regplot('2009','2010',top,ax=ax[1], scatter_kws={'alpha':0.4})

# %%
#The line of best fit is calculated by minimizing the ordinary least squares error function, that Seaborn module does automatically using the regplot function.
#The shaded area around the line represents 95% confidence intervals.

# %%
#To visualize the residuals in each case, Seaborn can also be used to create residual plot .
fig, ax = plt.subplots(1,2)
ax[0]= sns.residplot('2005','2006', top,ax=ax[0], scatter_kws={'alpha':0.4})
ax[0].set_ylabel('2005 residual')
ax[1]=sns.residplot('2009','2010',top,ax=ax[1], scatter_kws={'alpha':0.4})
ax[1].set_ylabel('2010 residual')
# Out:
# Text(0, 0.5, '2010 residual')

# %%
# Next we’ll want to fit a linear regression model. We need to choose variables that we think we’ll be good predictors for the dependent variable.
# This can be done by checking the correlation(s) between variables, on what variables are good predictors of y.

import statsmodels.api as sm

X = top["2005"]
y = top["2006"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# C:\Users\susie\Anaconda3\lib\site-packages\scipy\stats\stats.py:1416: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   2006   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     3777.
# Date:                Mon, 05 Aug 2019   Prob (F-statistic):           4.03e-13
# Time:                        23:15:43   Log-Likelihood:                -91.253
# No. Observations:                  10   AIC:                             184.5
# Df Residuals:                       9   BIC:                             184.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
# OLS stands for Ordinary Least Squares and the method “Least Squares” means that we’re trying to fit a regression line that
# would minimize the square of distance from the regression line.

# %%
X = top["2005"] ## X usually means our input variables (or independent variables)
y = top["2006"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# C:\Users\susie\Anaconda3\lib\site-packages\scipy\stats\stats.py:1416: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   2006   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     1094.
# Date:                Tue, 06 Aug 2019   Prob (F-statistic):           7.61e-10
# Time:                        01:45:07   Log-Likelihood:                -90.874
# No. Observations:                  10   AIC:                             185.7
# Df Residuals:                       8   BIC:                             186.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
#  With the constant term the coefficients are different. Without a constant we are forcing our model to go through the origin,
#but now we have a y-intercept at -34.67. We also changed the slope of the 2014 predictor from 0.9155 to 0.8976.

# %%
outliers=[]
def detect_outlier(low):
    
    threshold=3
    mean_1 = np.mean(low)
    std_1 =np.std(low)

# %%
outlier_datapoints1 = detect_outlier(low)
print(outlier_datapoints1)
# Out:
# None
